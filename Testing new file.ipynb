# %%
import pandas as pd

# %%
df = pd.read_csv('fullzip')
df
# Out:
#        Unnamed: 0     id        lat        lng  \
# 0               0      0  40.297876 -75.581294
# 1               1      1  40.258061 -75.264680
# 2               2      2  40.121182 -75.351975
# 3               3      3  40.116153 -75.343513
# 4               4      4  40.251492 -75.603350
# 5               5      5  40.253473 -75.283245
# 6               6      6  40.182111 -75.127795
# 7               7      7  40.217286 -75.405182
# 8               8      8  40.289027 -75.399590
# 9               9      9  40.102398 -75.291458
# 10             10     10  40.231990 -75.251891
# 11             11     15  40.223778 -75.235399
# 12             12     14  40.097222 -75.376195
# 13             13     11  40.084161 -75.308386
# 14             14     12  40.174131 -75.098491
# 15             15     13  40.062974 -75.135914
# 16             16     16  40.243258 -75.286552
# 17             17     17  40.312181 -75.574260
# 18             18     18  40.114239 -75.338508
# ...

# %%
df.columns = ["Redundant", u'id', u'lat', u'lng', u'desc', u'zip', u'timeStamp',
       u'twp', u'addr', u'e', u'emergencytype', u'emergencysubtype']

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df
# Out:
#           id        lat        lng  \
# 0          0  40.297876 -75.581294
# 1          1  40.258061 -75.264680
# 2          2  40.121182 -75.351975
# 3          3  40.116153 -75.343513
# 4          4  40.251492 -75.603350
# 5          5  40.253473 -75.283245
# 6          6  40.182111 -75.127795
# 7          7  40.217286 -75.405182
# 8          8  40.289027 -75.399590
# 9          9  40.102398 -75.291458
# 10        10  40.231990 -75.251891
# 11        15  40.223778 -75.235399
# 12        14  40.097222 -75.376195
# 13        11  40.084161 -75.308386
# 14        12  40.174131 -75.098491
# 15        13  40.062974 -75.135914
# 16        16  40.243258 -75.286552
# 17        17  40.312181 -75.574260
# 18        18  40.114239 -75.338508
# 19        19  40.209337 -75.135266
# 20        20  40.114239 -75.338508
# 21        21  40.117948 -75.209848
# 22        22  40.199006 -75.300058
# 23        24  40.153268 -75.189558
# 24        23  40.143326 -75.422819
# ...
